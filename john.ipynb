# %%
import pandas as pd
import matplotlib.pyplot as plt

# Telling Jupyter to render charts inline directly below the code cell
# %matplotlib inline

# Constructing the dataframe directly from your document logs
raw_data = [
    {"Date": "31/12/2022", "Location": "Iran", "Industry": "Public Administration", "Motive": "Protest"},
    {"Date": "31/12/2022", "Location": "United States", "Industry": "Public Administration", "Motive": "Financial"},
    {"Date": "30/12/2022", "Location": "Poland", "Industry": "Public Administration", "Motive": "Protest"},
    {"Date": "30/12/2022", "Location": "United States", "Industry": "Health Care", "Motive": "Undetermined"},
    {"Date": "30/12/2022", "Location": "Iran", "Industry": "Transportation", "Motive": "Protest"},
    {"Date": "29/12/2022", "Location": "United States", "Industry": "Information", "Motive": "Financial"},
    {"Date": "29/12/2022", "Location": "United States", "Industry": "Finance and Insurance", "Motive": "Undetermined"},
    {"Date": "29/12/2022", "Location": "United States", "Industry": "Health Care", "Motive": "Undetermined"},
    {"Date": "28/12/2022", "Location": "Estonia", "Industry": "Finance and Insurance", "Motive": "Financial"},
    {"Date": "28/12/2022", "Location": "Italy", "Industry": "Health Care", "Motive": "Financial"},
    {"Date": "28/12/2022", "Location": "Malaysia", "Industry": "Information", "Motive": "Financial"},
    {"Date": "28/12/2022", "Location": "Spain", "Industry": "Professional Services", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "United States", "Industry": "Finance and Insurance", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "Japan", "Industry": "Finance and Insurance", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "Viet Nam", "Industry": "Finance and Insurance", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "United Arab Emirates", "Industry": "Finance and Insurance", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "United States", "Industry": "Manufacturing", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "India", "Industry": "Transportation", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "Canada", "Industry": "Mining and Quarrying", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "Italy", "Industry": "Professional Services", "Motive": "Financial"},
    {"Date": "27/12/2022", "Location": "United States", "Industry": "Information", "Motive": "Undetermined"},
    {"Date": "26/12/2022", "Location": "United States", "Industry": "Professional Services", "Motive": "Undetermined"},
    {"Date": "25/12/2022", "Location": "Portugal", "Industry": "Transportation", "Motive": "Financial"},
    {"Date": "25/12/2022", "Location": "Malaysia", "Industry": "Information", "Motive": "Undetermined"},
    {"Date": "25/12/2022", "Location": "Malaysia", "Industry": "Finance and Insurance", "Motive": "Undetermined"},
    {"Date": "25/12/2022", "Location": "Malaysia", "Industry": "Public Administration", "Motive": "Undetermined"},
    {"Date": "23/12/2022", "Location": "United States", "Industry": "Information", "Motive": "Financial"},
    {"Date": "23/12/2022", "Location": "United Kingdom", "Industry": "Retail Trade", "Motive": "Undetermined"},
    {"Date": "22/12/2022", "Location": "United States", "Industry": "Health Care", "Motive": "Protest"},
    {"Date": "22/12/2022", "Location": "United States", "Industry": "Health Care", "Motive": "Undetermined"},
]

df = pd.DataFrame(raw_data)
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
# Create a cross-tabulation table of Location vs Motive
loc_motive = pd.crosstab(df['Location'], df['Motive'])

# Sort the table by total attacks so the most hit countries appear first
loc_motive['Total'] = loc_motive.sum(axis=1)
loc_motive = loc_motive.sort_values(by='Total', ascending=True).drop(columns='Total')

# Plot as a visually stacked horizontal bar chart
loc_motive.plot(kind='barh', stacked=True, figsize=(11, 6),
                colormap='viridis', edgecolor='black')

plt.title('Attack Motives Across Different Locations', fontsize=14, fontweight='bold')
plt.xlabel('Number of Incidents', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.legend(title='Attacker Motive', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='x', linestyle=':', alpha=0.6)

plt.tight_layout()
plt.show()
